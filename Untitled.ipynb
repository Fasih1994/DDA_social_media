# %%
import os
from dotenv import load_dotenv
import tweepy
import pandas as pd
from utils import TWEET_FIELDS, USER_FIELDS, EXPANSIONS

# %%
load_dotenv()
# Out:
# True

# %%
key_terms = '#DigitalDubai, Digital Dubai, #دبي_الرقمية, #DubaiNow, دبي الرقمية'.split(', ')
key_terms
# Out:
# ['#DigitalDubai', 'Digital Dubai', '#دبي_الرقمية', '#DubaiNow', 'دبي الرقمية']

# %%
client = tweepy.Client(
    bearer_token=os.environ['BEARER_TOKEN'],wait_on_rate_limit=True
)

# %%
tweet_fields = ['author_id','conversation_id','created_at',
                'geo','id','in_reply_to_user_id','lang',
                'possibly_sensitive','public_metrics','referenced_tweets',
                'source','text']
response = client.search_recent_tweets(
    f'"{key_terms[0]}" ', 
    tweet_fields=TWEET_FIELDS, 
    user_fields=USER_FIELDS,
    place_fields=['contained_within', 'country', 'country_code', 'full_name', 'geo', 'id', 'name', 'place_type'],
    expansions=EXPANSIONS, 
    max_results=100
)

# %%
response.includes
# Out:
# {'users': [<User id=1516745954426503168 name=CEO Insights Asia username=CEOInsightsAsi2>,
#   <User id=628870776 name=️Sagittarius♐️ username=M_rwah89>,
#   <User id=79970951 name=Digital Dubai دبي الرقمية username=DigitalDubai>,
#   <User id=1579649444869541888 name=H username=missstylish31>,
#   <User id=504978631 name=طارق الجناحي username=TariqAlJanahi>,
#   <User id=850773228 name=الصـقـور المخـلصيـن username=bu_Lateifa>,
#   <User id=916207218005102592 name=Younus Al Nasser username=younusalnasser>,
#   <User id=34675872 name=Tariq Haddad username=TariqHaddad>,
#   <User id=777255505915998208 name=د. نسرين سليمان username=kocavnin5od>,
#   <User id=303808116 name=هيئة الصحة بدبي username=DHA_Dubai>,
#   <User id=1682777241522954245 name=Fareed Fouad username=fareedfouaad>,
#   <User id=1538325356603637761 name=Farid Fouad username=Fareed_Fouaad>,
#   <User id=1694035421850714112 name=DUB_IRELAND username=DUB_IRELAND>,
#   <User id=1700038518943227904 name=د. عادل العمري username=Dr_AdelsAlomre>,
#   <User id=1699169650880192512 name=🇲🇽Sir Vic🇺🇲 username=DUB__KansasUSA>,
#   <User id=1468828914227232773 name=Agent | $DUB username=DUB_UyoNGR>,
#   <User id=879010221082816512 name=Dream Cab Jaipur username=dreamcabjaipur>,
#   <User id=1377943469868650497 name=Ammar username=DUB__Jordan>,
#   <User id=22592731 name=edge ME username=edgemiddleeast>,
#   <User id=1594031532162912263 name=carolyn 🫦 username=Carolyn__5117>,
#   <User id=1680892855710257154 name=Dodge username=DUB_NEWZEALAND>,
#   <User id=732892432145088512 name=Athiq Khan username=Dub_KarIN>,
#   <User id=1474969280571580420 name=TicaLouise username=MeowskiSuperCat>,
#   <User id=3508252635 name=Crypto Luffy username=Tez4ever_>,
#   <User id=1604192108646203392 name=tony_crypto 🏴󠁧󠁢󠁥󠁮󠁧󠁿 username=DUB_England>,
#   <User id=1136993669851025413 name=Ola __ username=DUB_CapeCoastGH>,
#   <User id=1697592658477080576 name=الغشمري username=alghshmry233306>,
#   <User id=1386699297752817666 name=@Poncho_DUB username=DUB_USA_OHIO>,
#   <User id=1418324445589032972 name=fracta.sats username=DUB_Venezuela>,
#   <User id=1599920304649867265 name=Rich_Guin Nft Collection username=Rich_GuinNFT>,
#   <User id=1008098359935107072 name=Mo_81078 🇦🇪 username=81078Mo>,
#   <User id=1543711085341155328 name=TheGOAT135 username=fdanconst>,
#   <User id=1632723096833753088 name=favak819 username=favak819>,
#   <User id=1463574965958098954 name=Sulphuric username=Sulphuric_rare>,
#   <User id=1376964750681194510 name=Crypto Governor username=DUB_NIGERIA>,
#   <User id=1690373245617295360 name=lee username=DUBScotland>,
#   <User id=1694006597440212992 name=DUB_FRANCE username=DUB_FRANCE>,
#   <User id=1393284152615522305 name=DUBX_SAITA username=Dubx_Saitama>,
#   <User id=1662951734480625664 name=Centauro65gs username=Centauro65gs>,
#   <User id=1624025435058188289 name=SHIB username=Shehzad75937212>,
#   <User id=1583523985559527424 name=BRENDAN 🟢 username=ClewesBrendan>,
#   <User id=1693772262758133760 name=DUB_BC_CA username=DUB_BC_CA>,
#   <User id=1190970501100965888 name=amin huda username=RajuRaj14246759>,
#   <User id=1449008022051774464 name=Dr.Putz username=DUB_Alaska>,
#   <User id=1350619268036108288 name=Steve Spirit @DUB_NIRL username=DUB_NIRL>,
#   <User id=1002989698179006464 name=Slim.hbar username=slim_gringo>,
#   <User id=386697436 name=W3¥ DUB_FirstLady username=DUB_AFRICA>,
#   <User id=43625006 name=Don Strickland Dub_VictoriaBC username=DUB_Vic_BC_CA>,
#   <User id=1583407082136633347 name=DUB_CORPORATION username=DUB_CORP>,
#   <User id=1338182404679274496 name=SiriusA☀️ username=DUB_MIAMIUSA>,
#   <User id=1131694596 name=CryptoRacer username=IAmCryptoRacer>,
#   <User id=1680311424374169600 name=mike username=xrp_believer23>,
#   <User id=1589337259635245056 name=Ben username=DUB_WA_USA>,
#   <User id=2559774491 name=MrFits.eth username=vburch6>,
#   <User id=1692642921147662336 name=@DUB_PCB_FL_USA username=DUB_PCB_FL_USA>,
#   <User id=2751814549 name=Syed Muhammad Saim username=DUB_Pak>,
#   <User id=1465891906920099845 name=KuyaDUBX username=KuyaDUBX>,
#   <User id=1509206479475298305 name=IAmCryptoWolfy username=IAmCryptoWolfy>,
#   <User id=1139771901348175873 name=Raj Kumar username=iamrajofficials>,
#   <User id=2743796222 name=mateux carneiro 🐍 username=mateuxcarneiro>,
#   <User id=1187718400778194944 name=二乃＠LOL username=ninochLOL>,
#   <User id=109641901 name=amalgama.ETH username=amalgama_E1h>,
#   <User id=1213931277344071680 name=Ace_Sardonic username=Ace_Sardonic>,
#   <User id=1642720552946135040 name=حمد ا username=hhaammaad2023>,
#   <User id=1571671999490949121 name=Bigboi.hbar username=Big96boi_1>,
#   <User id=850023448357351430 name=HBARd username=p_bard146>,
#   <User id=592687163 name=هيثم الجهوري | Haitham Al-Jahwari username=Hai4am_jahwari>],
#  'places': [<Place id=bdac430362da0893 full_name=Ixtlahuacán de los Membrillos, Jalisco>]}

# %%
response.includes['users'][0].data
# Out:
# {'id': '1516745954426503168',
#  'username': 'CEOInsightsAsi2',
#  'location': 'Noida',
#  'name': 'CEO Insights Asia'}

# %%
response.data['public_metrics']
# Out:
# {'retweet_count': 0,
#  'reply_count': 2,
#  'like_count': 1,
#  'quote_count': 0,
#  'bookmark_count': 0,
#  'impression_count': 68}

# %%
for record in response.data:
    # print(record)
    if record.data['public_metrics']['reply_count']!=0:
        print(record.data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 3
#       1 for record in response.data:
#       2     # print(record)
# ----> 3     if record.data['public_metrics']['reply_count']!=0:
#       4         print(record.data)
#
# AttributeError: 'str' object has no attribute 'data'

# %%
response = client.search_recent_tweets(
    "Python",
    tweet_fields=tweepy.PUBLIC_TWEET_FIELDS,
    expansions=["attachments.media_keys", "author_id"],

)
response
# Out:
# Response(data=[<Tweet id=1695069044590727618 text='RT @RalGhanmi: 🎥اكثر لغة #برمجة طلباً من عام ٢٠٠٠ الى اليوم ؟ \n\nسواء كنت في صناعة #الامن_السيبراني او #غيرها كمبرمج انصحك تنطلق من اشهر لغة…'>, <Tweet id=1695069012840050772 text='Pythonソースコード （1/2）\n\n微分が面倒になるというデメリットはありますが，自然現象は球対称（に近似できる）ものが多いので球座標を導入するメリットは十分に大きいです．とにかく「基底ベクトルの動き」のイメージは重要かと思います． https://t.co/Jnky0H3zpL'>, <Tweet id=1695068958276120676 text="@phosphorus_phi oooh I'm learning a tiny bit of C# myself cuz I need it for my embedded software jobs, otherwise I love coding C++ and Python \n\nall the best with the game design! 😍👌">, <Tweet id=1695068940559385038 text='RT @dev2death1: #html #css #javascript #Web3 #web #developer #linux #c++ #asp #ReactJS #vuejs #laravel #rust #golang #python #dev #twitter…'>, <Tweet id=1695068925849940089 text='RT @MoureDev: En este vídeo puedes ver en acción lo último de Microsoft... Python para Excel!\n\nHasta el propio creador de Python, Guido van…'>, <Tweet id=1695068920032702481 text='Python嫌いの私だが、これはよい使い方\n\nhttps://t.co/pEeZGsKQeG'>, <Tweet id=1695068888667398505 text='@AnlasEkonomi Ben excelin yok olmasından çok python bilmenin bir gereklilik olmaktan çıkacağını, dummyler icin basit bir gui oluşacağını düşünüyorum. İçinden geçilen şu dönem bana 80leri hatırlatıyor. Herkes dos, fortran, pascal vs bilmek zorundaydı. Windows ile bu gereklilik ortadan kalktı.'>, <Tweet id=1695068888403206425 text='Hey @everyone, If given the choice would you write Python over JavaScript in the context of a full-stack app? The Python in question will be transformed to JS ahead of time with performance, efficiency, and readability in mind'>, <Tweet id=1695068883307139099 text='Pythonが好きすぎるので、NimをすることでちょっとずつC++に慣れていこう(？)'>, <Tweet id=1695068859651203374 text='RT @ciberneos: - Curso muy recomendado, Python desde 0. Paso a paso.\nhttps://t.co/Ggf7kWy03N'>], includes={'users': [<User id=1694045579054026752 name=اكثر مقطع منتشر username=akthr38461>, <User id=1367023826974859265 name=リニア・テック 別府 伸耕 username=linear_tec>, <User id=1489542691570556928 name=Art Dei Tech username=ArtDeiTech>, <User id=1409602827287212046 name=dev2death username=dev2death1>, <User id=1475845984508952580 name=Fernando Garcia username=FermanyusG>, <User id=2273995242 name=よしのたろう 🍥純国産ボード”スプレッセンス”応援団長（仮） username=Taro_Yoshino>, <User id=42195310 name=Uluç Yurtal username=Miklagardian>, <User id=1674662240937705473 name=NormVg username=TheNormVg>, <User id=1355776527799996417 name=けむにく@競プロ username=kemuniku>, <User id=1355284424301142016 name=elori username=elori_valerian>], 'media': [<Media media_key=3_1695064370668052480 type=photo>]}, errors=[], meta={'newest_id': '1695069044590727618', 'oldest_id': '1695068859651203374', 'result_count': 10, 'next_token': 'b26v89c19zqg8o3fqkrzn7532l4kq71c77fdl4gjer0cd'})

# %%
response.data[0].data
# Out:
# {'text': 'RT @RalGhanmi: 🎥اكثر لغة #برمجة طلباً من عام ٢٠٠٠ الى اليوم ؟ \n\nسواء كنت في صناعة #الامن_السيبراني او #غيرها كمبرمج انصحك تنطلق من اشهر لغة…',
#  'conversation_id': '1695069044590727618',
#  'referenced_tweets': [{'type': 'retweeted', 'id': '1695067602605744385'}],
#  'public_metrics': {'retweet_count': 2,
#   'reply_count': 0,
#   'like_count': 0,
#   'quote_count': 0,
#   'bookmark_count': 0,
#   'impression_count': 0},
#  'lang': 'ar',
#  'possibly_sensitive': False,
#  'created_at': '2023-08-25T13:42:07.000Z',
#  'reply_settings': 'everyone',
#  'entities': {'mentions': [{'start': 3,
#     'end': 13,
#     'username': 'RalGhanmi',
#     'id': '59061937'}],
#   'hashtags': [{'start': 25, 'end': 31, 'tag': 'برمجة'},
#    {'start': 82, 'end': 98, 'tag': 'الامن_السيبراني'},
#    {'start': 102, 'end': 108, 'tag': 'غيرها'}]},
#  'context_annotations': [{'domain': {'id': '46',
#     'name': 'Business Taxonomy',
#     'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#    'entity': {'id': '1557697333571112960',
#     'name': 'Technology Business',
#     'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}},
#   {'domain': {'id': '30',
#     'name': 'Entities [Entity Service]',
#     'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'},
#    'entity': {'id': '848920371311001600',
#     'name': 'Technology',
#     'description': 'Technology and computing'}},
#   {'domain': {'id': '30',
#     'name': 'Entities [Entity Service]',
#     'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'},
#    'entity': {'id': '898650876658634752',
#     'name': 'Cybersecurity',
#     'description': 'Cybersecurity'}},
#   {'domain': {'id': '131',
#     'name': 'Unified Twitter Taxonomy',
#     'description': 'A taxonomy of user interests. '},
#    'entity': {'id': '847878884917886977',
#     'name': 'Politics',
#     'description': 'Politics'}},
#   {'domain': {'id': '131',
#     'name': 'Unified Twitter Taxonomy',
#     'description': 'A taxonomy of user interests. '},
#    'entity': {'id': '848920371311001600',
#     'name': 'Technology',
#     'description': 'Technology and computing'}},
#   {'domain': {'id': '131',
#     'name': 'Unified Twitter Taxonomy',
#     'description': 'A taxonomy of user interests. '},
#    'entity': {'id': '898650876658634752',
#     'name': 'Cybersecurity',
#     'description': 'Cybersecurity'}},
#   {'domain': {'id': '131',
#     'name': 'Unified Twitter Taxonomy',
#     'description': 'A taxonomy of user interests. '},
#    'entity': {'id': '900740740468191232',
#     'name': 'Political issues',
#     'description': 'Political issues'}},
#   {'domain': {'id': '131',
#     'name': 'Unified Twitter Taxonomy',
#     'description': 'A taxonomy of user interests. '},
#    'entity': {'id': '1047123725525479425',
#     'name': 'Information security',
#     'description': 'Information Security'}},
#   {'domain': {'id': '131',
#     'name': 'Unified Twitter Taxonomy',
#     'description': 'A taxonomy of user interests. '},
#    'entity': {'id': '1088443224425807872',
#     'name': 'Information Privacy Worldwide',
#     'description': 'Information Privacy'}}],
#  'id': '1695069044590727618',
#  'edit_controls': {'edits_remaining': 5,
#   'is_edit_eligible': False,
#   'editable_until': datetime.datetime(2023, 8, 25, 14, 42, 7, tzinfo=datetime.timezone.utc)},
#  'edit_history_tweet_ids': ['1695069044590727618'],
#  'author_id': '1694045579054026752'}

# %%
users
# Out:
# {389750842: <User id=389750842 name=Cumbria, UK  ☀ ☀ username=G1CAE>,
#  1693551814686461952: <User id=1693551814686461952 name=wakeytech username=wakeytech>,
#  943925946: <User id=943925946 name=Peter 🇪🇺 🇺🇦 username=Tpzijl>}

# %%
print("USER Fields:")
for field in tweepy.USER_FIELDS:
    print("\t - "+field)
print("\ntweet Fields:")
for field in tweepy.TWEET_FIELDS:
    print("\t - "+field)
# Out:
# USER Fields:
# 	 - created_at
# 	 - description
# 	 - entities
# 	 - id
# 	 - location
# 	 - name
# 	 - pinned_tweet_id
# 	 - profile_image_url
# 	 - protected
# 	 - public_metrics
# 	 - url
# 	 - username
# 	 - verified
# 	 - verified_type
# 	 - withheld
#
# tweet Fields:
# 	 - attachments
# 	 - author_id
# 	 - context_annotations
# 	 - conversation_id
# 	 - created_at
# 	 - edit_controls
# 	 - edit_history_tweet_ids
# 	 - entities
# 	 - geo
# 	 - id
# 	 - in_reply_to_user_id
# 	 - lang
# 	 - possibly_sensitive
# 	 - public_metrics
# 	 - referenced_tweets
# 	 - reply_settings
# 	 - source
# 	 - text
# 	 - withheld
# 	 - non_public_metrics
# 	 - organic_metrics
# 	 - promoted_metrics

# %%
def flatten_dict(d ):
    """
    Recursively flatten a nested dictionary.

    Args:
    d (dict): The input dictionary.
    parent_key (str): The key representing the parent in the flattened dictionary.
    sep (str): Separator used to concatenate keys.

    Returns:
    dict: A flattened dictionary.
    """
    items = []
    for key, value in d.items():
        new_key = f"{key}"
        if isinstance(value, dict):
            items.extend(flatten_dict(value).items())
        else:
            items.append((new_key, value))
    return dict(items)

# %%
columns = ['tweet_id', 'author_id', 'key_term', 'text',
           'possibly_sensitive', 'lang', 'created_at', 
           'retweet_count', 'reply_count', 'like_count', 
           'quote_count', 'bookmark_count', 'impression_count', 
           'conversation_id']

# %%
data_dict = {}
key_term = key_terms[0]
for record in response.data:
    data = flatten_dict(record.data)
    for column in columns:
        if column in data_dict:
            data_dict[column].append(data.get(column) if column!='key_term' else key_term)
        else: 
            data_dict[column]=[ data.get(column) if column!='key_term' else key_term]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[181], line 11
#       8     data_dict[column].append(key_term)
#      10 elif column in ['username', 'name']:
# ---> 11     data_dict[column].append(response.includes['users'][i][column])
#      13 else:
#      14     data_dict[column].append(data.get(column))
#
# IndexError: list index out of range

# %%
# Out:
# 10

# %%
df1 =  pd.DataFrame(data_dict)
df1['created_at'] = pd.to_datetime(df1['created_at'])
df1
# Out:
#                     id            author_id       key_term  \
# 0  1697536092709478855  1695687288242769920  #DigitalDubai
# 1  1697535722826133716           2743951200  #DigitalDubai
# 2  1697529035155177828           2290047925  #DigitalDubai
# 3  1697524245914321158  1689606195466682368  #DigitalDubai
# 4  1697524220496851453  1689606195466682368  #DigitalDubai
# 5  1697524200095748495  1689606195466682368  #DigitalDubai
# 6  1697524180810449173  1689606195466682368  #DigitalDubai
# 7  1697523722893074671  1689606195466682368  #DigitalDubai
# 8  1697523556941242441  1689606195466682368  #DigitalDubai
# 9  1697523413135327293  1689606195466682368  #DigitalDubai
#
#                                                 text  possibly_sensitive lang  \
# 0  RT @jayjitbiswas: @IrinaHeaver @DigitalDubai @...               False   en
# 1  RT @DigitalDubai: اليوم ليس كالأمس، فقد اصبح ع...               False   ar
# 2  @HHShkMohd @DubaiDET @TECofDubai @DTMCentre @v...               False   en
# 3  RT @DigitalDubai: مع تطبيق #دبي_الآن، يمكنك إد...               False  und
# 4  RT @DigitalDubai: مع منصة #دبي_بالس، يمكنك الو...               False  und
# 5  RT @DigitalDubai: حان الوقت لتوقيع "العقد المد...               False   ar
# 6  RT @DigitalDubai: Time to sign your ‘Parent Co...               False   en
# 7  RT @DigitalDubai: كل عام والمرأة الإماراتية مل...               False   ar
# 8  RT @DigitalDubai: بمناسبة #يوم_المرأة_الإمارات...               False   ar
# 9  RT @DigitalDubai: #رقميات: بلغ عدد معاملات تطب...               False  und
#
#                  created_at  retweet_count  reply_count  like_count  \
# 0 2023-09-01 09:05:17+00:00             22            0           0
# 1 2023-09-01 09:03:49+00:00             31            0           0
# 2 2023-09-01 08:37:15+00:00              0            0           0
# 3 2023-09-01 08:18:13+00:00              2            0           0
# 4 2023-09-01 08:18:07+00:00              2            0           0
# 5 2023-09-01 08:18:02+00:00              3            0           0
# 6 2023-09-01 08:17:57+00:00              1            0           0
# 7 2023-09-01 08:16:08+00:00              3            0           0
# 8 2023-09-01 08:15:29+00:00              1            0           0
# 9 2023-09-01 08:14:54+00:00              2            0           0
#
#    quote_count  bookmark_count  impression_count      conversation_id
# 0            0               0                 0  1697536092709478855
# 1            0               0                 0  1697535722826133716
# 2            0               0                13  1697521927210840575
# 3            0               0                 0  1697524245914321158
# 4            0               0                 0  1697524220496851453
# 5            0               0                 0  1697524200095748495
# 6            0               0                 0  1697524180810449173
# 7            0               0                 0  1697523722893074671
# 8            0               0                 0  1697523556941242441
# 9            0               0                 0  1697523413135327293

# %%
df2 = pd.concat([df,df1]).reset_index().drop(columns=['index'])

# %%
df2
# Out:
#     possibly_sensitive lang                created_at  retweet_count  \
# 0                False   en 2023-09-01 08:11:41+00:00              0
# 1                False   en 2023-08-29 10:20:11+00:00              0
# 2                False   en 2023-08-28 05:36:47+00:00              0
# 3                False   ar 2023-08-26 08:47:54+00:00              0
# 4                False   en 2023-08-26 06:18:55+00:00              0
# 5                False   en 2023-09-01 09:05:17+00:00             22
# 6                False   ar 2023-09-01 09:03:49+00:00             31
# 7                False   en 2023-09-01 08:37:15+00:00              0
# 8                False  und 2023-09-01 08:18:13+00:00              2
# 9                False  und 2023-09-01 08:18:07+00:00              2
# 10               False   ar 2023-09-01 08:18:02+00:00              3
# 11               False   en 2023-09-01 08:17:57+00:00              1
# 12               False   ar 2023-09-01 08:16:08+00:00              3
# 13               False   ar 2023-09-01 08:15:29+00:00              1
# 14               False  und 2023-09-01 08:14:54+00:00              2
#
#     reply_count  like_count  quote_count  bookmark_count  impression_count  \
# 0             0           0            0               0                 2
# 1             0           0            0               0               126
# 2             0           0            0               0                12
# 3             0           0            0               0                 8
# 4             0           1            0               0               395
# 5             0           0            0               0                 0
# 6             0           0            0               0                 0
# 7             0           0            0               0                13
# 8             0           0            0               0                 0
# 9             0           0            0               0                 0
# 10            0           0            0               0                 0
# 11            0           0            0               0                 0
# 12            0           0            0               0                 0
# 13            0           0            0               0                 0
# 14            0           0            0               0                 0
#
#         conversation_id                   id            author_id  \
# 0   1697522601873093031  1697522601873093031  1697488205635829760
# 1   1696467776062321116  1696467776062321116           4823816207
# 2   1696034068817678840  1696034068817678840  1650870530160099329
# 3   1695357388923060280  1695357388923060280  1514533481522552841
# 4   1695319894697333058  1695319894697333058  1650870530160099329
# 5   1697536092709478855  1697536092709478855  1695687288242769920
# 6   1697535722826133716  1697535722826133716           2743951200
# 7   1697521927210840575  1697529035155177828           2290047925
# 8   1697524245914321158  1697524245914321158  1689606195466682368
# 9   1697524220496851453  1697524220496851453  1689606195466682368
# 10  1697524200095748495  1697524200095748495  1689606195466682368
# 11  1697524180810449173  1697524180810449173  1689606195466682368
# 12  1697523722893074671  1697523722893074671  1689606195466682368
# 13  1697523556941242441  1697523556941242441  1689606195466682368
# 14  1697523413135327293  1697523413135327293  1689606195466682368
#
#                                                  text
# 0   we launched the Dubai Digital Cloud project, t...
# 1   Digital Dubai launches private sector #cyberse...
# 2   "Where Creativity Meets Analytics: Sculpting S...
# 3   العلامة التجارية هي واجهتك وأساس أعمالك🎀اختَر ...
# 4   "The Digital Playground: Where Brands Come to ...
# 5   RT @jayjitbiswas: @IrinaHeaver @DigitalDubai @...
# 6   RT @DigitalDubai: اليوم ليس كالأمس، فقد اصبح ع...
# 7   @HHShkMohd @DubaiDET @TECofDubai @DTMCentre @v...
# 8   RT @DigitalDubai: مع تطبيق #دبي_الآن، يمكنك إد...
# 9   RT @DigitalDubai: مع منصة #دبي_بالس، يمكنك الو...
# 10  RT @DigitalDubai: حان الوقت لتوقيع "العقد المد...
# 11  RT @DigitalDubai: Time to sign your ‘Parent Co...
# 12  RT @DigitalDubai: كل عام والمرأة الإماراتية مل...
# 13  RT @DigitalDubai: بمناسبة #يوم_المرأة_الإمارات...
# 14  RT @DigitalDubai: #رقميات: بلغ عدد معاملات تطب...

# %%
user_dict = {}
USER_FIELDS = ['name', 'username', 'id']
for user in response.includes['users']:
    for field in USER_FIELDS:
        if field in user_dict:
            user_dict[field].append(user[field])
        else:
            user_dict[field] = [user[field]]

users_df = pd.DataFrame(user_dict)

# %%
df = pd.read_csv('tweet.csv')

# %%
df.drop(columns=['Unnamed: 0','Unnamed: 0.2','Unnamed: 0.1'], inplace=True)

# %%
df
# Out:
#                        id            author_id       key_term  \
# 0     1697596402212237438            125273218  #DigitalDubai
# 1     1697593881880137805            245243568  #DigitalDubai
# 2     1697536092709478855  1695687288242769920  #DigitalDubai
# 3     1697535722826133716           2743951200  #DigitalDubai
# 4     1697529035155177828           2290047925  #DigitalDubai
# ...                   ...                  ...            ...
# 1161  1696910787653030172  1463911525148729348    دبي الرقمية
# 1162  1696910748734152887  1203366448099471360    دبي الرقمية
# 1163  1696910505988755643            952378387    دبي الرقمية
# 1164  1696910426548621479            445293273    دبي الرقمية
# 1165  1696909628536131934             79970951    دبي الرقمية
#
#                                                    text  possibly_sensitive  \
# 0     RT @ibahzad: #خلك_واعي : اليوم ليس كالأمس، فقد...               False
# 1     RT @DigitalDubai: اليوم ليس كالأمس، فقد اصبح ع...               False
# 2     RT @jayjitbiswas: @IrinaHeaver @DigitalDubai @...               False
# 3     RT @DigitalDubai: اليوم ليس كالأمس، فقد اصبح ع...               False
# 4     @HHShkMohd @DubaiDET @TECofDubai @DTMCentre @v...               False
# ...                                                 ...                 ...
# 1161  RT @ibahzad: #خلك_واعي : اليوم ليس كالأمس، فقد...               False
# 1162  RT @DigitalDubai: اليوم ليس كالأمس، فقد اصبح ع...               False
# 1163  RT @ibahzad: #خلك_واعي : اليوم ليس كالأمس، فقد...               False
# 1164  #خلك_واعي : اليوم ليس كالأمس، فقد أصبح يتعين ع...               False
# 1165  اليوم ليس كالأمس، فقد اصبح علينا الحذر أكثر وا...               False
#
#      lang                created_at  retweet_count  reply_count  like_count  \
# 0      ar  2023-09-01T13:04:56.000Z             24            0           0
# 1      ar  2023-09-01T12:54:55.000Z             32            0           0
# 2      en  2023-09-01T09:05:17.000Z             23            0           0
# 3      ar  2023-09-01T09:03:49.000Z             32            0           0
# 4      en  2023-09-01T08:37:15.000Z              0            0           0
# ...   ...                       ...            ...          ...         ...
# 1161   ar  2023-08-30T15:40:33.000Z             24            0           0
# 1162   ar  2023-08-30T15:40:24.000Z             32            0           0
# 1163   ar  2023-08-30T15:39:26.000Z             24            0           0
# 1164   ar  2023-08-30T15:39:07.000Z             24            3          75
# 1165   ar  2023-08-30T15:35:57.000Z             32            4          95
#
#       quote_count  bookmark_count  impression_count      conversation_id
# 0               0               0                 0  1697596402212237438
# 1               0               0                 0  1697593881880137805
# 2               0               0                 0  1697536092709478855
# 3               0               0                 0  1697535722826133716
# 4               0               0                14  1697521927210840575
# ...           ...             ...               ...                  ...
# 1161            0               0                 0  1696910787653030172
# 1162            0               0                 0  1696910748734152887
# 1163            0               0                 0  1696910505988755643
# 1164            0               0              4810  1696910426548621479
# 1165            0               5            113281  1696909628536131934
#
# [1166 rows x 14 columns]

# %%
df.to_csv("tweet.csv")

# %%
df.columns
# Out:
# Index(['id', 'author_id', 'key_term', 'text', 'possibly_sensitive', 'lang',
#        'created_at', 'retweet_count', 'reply_count', 'like_count',
#        'quote_count', 'bookmark_count', 'impression_count', 'conversation_id'],
#       dtype='object')

# %%
tweets = pd.read_csv('data/final.csv')
locations = pd.read_csv('data/UAE_Location.csv')

# %%
tweets.head()
# Out:
#               tweet_id                            name     username  \
# 0  1697596402212237438                         🇪🇬 𝓗𝓪𝓷𝔂      HanyAug
# 1  1697593881880137805  الحكومة الرقمية لدولة الامارات      uaedgov
# 2  1697536092709478855                        CLORINDA  CLORINcftDA
# 3  1697535722826133716                               ُ    _bluealya
# 4  1697529035155177828   #تبادل_ريتويت، #تابعني_اتابعك     ASB_5500
#
#              author_id       key_term  \
# 0            125273218  #DigitalDubai
# 1            245243568  #DigitalDubai
# 2  1695687288242769920  #DigitalDubai
# 3           2743951200  #DigitalDubai
# 4           2290047925  #DigitalDubai
#
#                                                 text  possibly_sensitive  \
# 0  RT @ibahzad: #خلك_واعي : اليوم ليس كالأمس، فقد...               False
# 1  RT @DigitalDubai: اليوم ليس كالأمس، فقد اصبح ع...               False
# 2  RT @jayjitbiswas: @IrinaHeaver @DigitalDubai @...               False
# 3  RT @DigitalDubai: اليوم ليس كالأمس، فقد اصبح ع...               False
# 4  @HHShkMohd @DubaiDET @TECofDubai @DTMCentre @v...               False
#
#                  created_at  retweet_count  reply_count  like_count  \
# 0  2023-09-01T13:04:56.000Z             24            0           0
# 1  2023-09-01T12:54:55.000Z             32            0           0
# 2  2023-09-01T09:05:17.000Z             23            0           0
# 3  2023-09-01T09:03:49.000Z             32            0           0
# 4  2023-09-01T08:37:15.000Z              0            0           0
#
#    quote_count  bookmark_count  impression_count      conversation_id  \
# 0            0               0                 0  1697596402212237438
# 1            0               0                 0  1697593881880137805
# 2            0               0                 0  1697536092709478855
# 3            0               0                 0  1697535722826133716
# 4            0               0                14  1697521927210840575
#
#   sentiment          tone language
# 0  positive      cautious   arabic
# 1   caution   informative   arabic
# 2  positive  appreciative  English
# 3   caution   informative   arabic
# 4  positive       neutral  English

# %%
locations.head()
# Out:
#          LAT       LONG
# 0  19.437706  57.216403
# 1  22.951536  47.418767
# 2  22.955754  54.197451
# 3  22.957037  54.197987
# 4  22.961878  54.156287

# %%
import numpy as np
tweets_with_locations = tweets.copy()
tweets_with_locations['lat'] = np.nan  # Initialize empty columns for lat and long
tweets_with_locations['long'] = np.nan

# %%
for index, row in tweets_with_locations.iterrows():
    random_location = locations.sample(n=1, random_state=index)
    tweets_with_locations.at[index,'lat'] = random_location['LAT'].values[0]
    tweets_with_locations.at[index,'long'] = random_location['LONG'].values[0]

# %%
tweets_with_locations.head()
# Out:
#               tweet_id                            name     username  \
# 0  1697596402212237438                         🇪🇬 𝓗𝓪𝓷𝔂      HanyAug
# 1  1697593881880137805  الحكومة الرقمية لدولة الامارات      uaedgov
# 2  1697536092709478855                        CLORINDA  CLORINcftDA
# 3  1697535722826133716                               ُ    _bluealya
# 4  1697529035155177828   #تبادل_ريتويت، #تابعني_اتابعك     ASB_5500
#
#              author_id       key_term  \
# 0            125273218  #DigitalDubai
# 1            245243568  #DigitalDubai
# 2  1695687288242769920  #DigitalDubai
# 3           2743951200  #DigitalDubai
# 4           2290047925  #DigitalDubai
#
#                                                 text  possibly_sensitive  \
# 0  RT @ibahzad: #خلك_واعي : اليوم ليس كالأمس، فقد...               False
# 1  RT @DigitalDubai: اليوم ليس كالأمس، فقد اصبح ع...               False
# 2  RT @jayjitbiswas: @IrinaHeaver @DigitalDubai @...               False
# 3  RT @DigitalDubai: اليوم ليس كالأمس، فقد اصبح ع...               False
# 4  @HHShkMohd @DubaiDET @TECofDubai @DTMCentre @v...               False
#
#                  created_at  retweet_count  reply_count  like_count  \
# 0  2023-09-01T13:04:56.000Z             24            0           0
# 1  2023-09-01T12:54:55.000Z             32            0           0
# 2  2023-09-01T09:05:17.000Z             23            0           0
# 3  2023-09-01T09:03:49.000Z             32            0           0
# 4  2023-09-01T08:37:15.000Z              0            0           0
#
#    quote_count  bookmark_count  impression_count      conversation_id  \
# 0            0               0                 0  1697596402212237438
# 1            0               0                 0  1697593881880137805
# 2            0               0                 0  1697536092709478855
# 3            0               0                 0  1697535722826133716
# 4            0               0                14  1697521927210840575
#
#   sentiment          tone language        lat       long
# 0  positive      cautious   arabic  24.303367  54.648523
# 1   caution   informative   arabic  24.466978  54.355888
# 2  positive  appreciative  English  24.376627  54.511478
# 3   caution   informative   arabic  24.365050  54.516962
# 4  positive       neutral  English  24.458552  54.363864

# %%
tweets_with_locations.to_csv('tweets_with_locations.csv', index=False)
